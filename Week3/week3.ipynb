# %%
import matplotlib.pyplot as plt
groups=["Group 1","Group 2","Group 3","Group 4"]
students=[10,101,13,20]
plt.pie(students,labels=groups,counterclock=False,autopct="%.2f",pctdistance=.5,radius=.9)
plt.show()

# %%
fig,sub=plt.subplots(3,2)
years=[2017,2018,2019,2020,2021,2022]
bears=[8,54,93,116,137,184]
dolphins=[150,77,32,11,6]
whales=[80,54,100,76,93,72]
# sub.plot()
